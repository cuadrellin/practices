# %% [markdown]
# <a href="https://colab.research.google.com/github/cuadrellin/practices/blob/main/Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

# %%
df = sns.load_dataset("iris")
df.iloc[:, :-1]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
pca_model = PCA(n_components=2)
df_pca = pca_model.fit_transform(df.iloc[:,:-1])
df_pca
# Out:
# array([[-2.68412563,  0.31939725],
#        [-2.71414169, -0.17700123],
#        [-2.88899057, -0.14494943],
#        [-2.74534286, -0.31829898],
#        [-2.72871654,  0.32675451],
#        [-2.28085963,  0.74133045],
#        [-2.82053775, -0.08946138],
#        [-2.62614497,  0.16338496],
#        [-2.88638273, -0.57831175],
#        [-2.6727558 , -0.11377425],
#        [-2.50694709,  0.6450689 ],
#        [-2.61275523,  0.01472994],
#        [-2.78610927, -0.235112  ],
#        [-3.22380374, -0.51139459],
#        [-2.64475039,  1.17876464],
#        [-2.38603903,  1.33806233],
#        [-2.62352788,  0.81067951],
#        [-2.64829671,  0.31184914],
#        [-2.19982032,  0.87283904],
#        [-2.5879864 ,  0.51356031],
#        [-2.31025622,  0.39134594],
#        [-2.54370523,  0.43299606],
#        [-3.21593942,  0.13346807],
#        [-2.30273318,  0.09870885],
#        [-2.35575405, -0.03728186],
#        [-2.50666891, -0.14601688],
#        [-2.46882007,  0.13095149],
# ...

# %%
plt.scatter(df_pca[:,0], df_pca[:,1], c=df["species"].astype("category").cat.codes)
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.show()

# %% [markdown]
# Transformación logaritmica

# %%
sns.displot(data=df, x="sepal_length", hue="species", kde=True)
plt.show()

# %% [markdown]
# La transformación logaritmica permite separar un poco las clases

# %%
df["sepal_length_log"] =np.log(df["sepal_length"])

sns.displot(data=df, x="sepal_length_log", hue="species", kde=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sepal_length_log
# 0            1.629241
# 1            1.589235
# 2            1.547563
# 3            1.526056
# ...

# %%
std_scaler = StandardScaler()
df_std_scaler = std_scaler.fit_transform(df.iloc[:,:-2])

# %%
mm_scaler =MinMaxScaler()
df_normalized = mm_scaler.fit_transform(df.iloc[:,:-2])
df_normalized
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %% [markdown]
#   CORRELACIÓN DE PEARSON: Nos dice qué tan bien se ajustan nuestros datos a una correlación lineal. Si es igual a 1 se ajustan perfectamente a una linea recta con pendiente positiva. Si es igual a -1, los datos se ajustan perfectamente a una línea recta con pendiente negativa.
#   Cualquier valor entre -1 y 1, nos habla acerca de la pendiente de esta recta y de la varianza que hay en estos datos al momento de ajustar esta recta.
#   nos permite ver qué variables se relacionan entre sí y poder hacer reducción de variables.

# %%
from scipy.stats import pearsonr
#Calcular la correlación de Pearson
correlacion, _ = pearsonr(df["sepal_length"], df["petal_length"])
print(f"La correlacion de pearson entre sepal length y petal length es: {correlacion}")
# Out:
# La correlacion de pearson entre sepal length y petal length es: 0.8717537758865831

# %% [markdown]
# Análisis de Clusters

# %%
from sklearn.cluster import KMeans

# %%
#Debemos generar el modelo
model = KMeans(n_clusters=3, random_state=42)   #nro de clusters es el nro de clases
df["cluster"] = model.fit_predict(df.iloc[:,:-2])
df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# ...

# %%
sns.scatterplot(data=df,x="sepal_length", y="petal_length", hue="cluster" )
plt.show()

# %% [markdown]
# DETECCIÓN DE OUTLAYERS

# %%
#Calcular el Z-score
df["z_score_sepal_length"] = np.abs((df["sepal_length"] - df["sepal_length"].mean())/df["sepal_length"].std())
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sepal_length_log  cluster  z_score_sepal_length
# 0            1.629241        1              0.897674
# ...

# %%
outliers = df[df["z_score_sepal_length"] > 2]
outliers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 105           7.6          3.0           6.6          2.1  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
#
#      sepal_length_log  cluster  z_score_sepal_length
# 105          2.028148        2              2.121409
# 117          2.041220        2              2.242172
# 118          2.041220        2              2.242172
# 122          2.041220        2              2.242172
# 131          2.066863        2              2.483699
# 135          2.041220        2              2.242172

# %%
sns.scatterplot(data= df, x="sepal_length", y="petal_length", hue="species")
sns.scatterplot(data=outliers, x="sepal_length", y="petal_length", c = "red")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>
